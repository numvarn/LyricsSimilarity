# %% [markdown]
# # Gensim Doc2Vec
#
# สำหรับสร้างโมเดลสำหรับการอกสารที่มีความคล้ายคลึงกัน (Document Similarity)

# %%
import gensim
import os
import pandas as pd
import random

# %%
'''
Read All Documents 
'''
path = "./data/05.lyrics_processed_final.csv"
data = pd.read_csv(path)

# %%
'''
Display Sample of Documents
'''
data.head()
# Out:
#    id             title        artist  emotion  emotion_sym  year  \
# 0   1       ขอใจกันหนาว    ต่าย อรทัย  กำลังใจ            0  2547
# 1   2   ดอกหญ้าในป่าปูน    ต่าย อรทัย  กำลังใจ            0  2546
# 2   3     กรรมกรแก้มแดง    ต่าย อรทัย  กำลังใจ            0  2557
# 3   4         ถนนค้นฝัน  ตั๊กแตน ชลดา  กำลังใจ            0  2550
# 4   5  นักร้องงานเลี้ยง  ตั๊กแตน ชลดา  กำลังใจ            0  2552
#
#                                                verse  \
# 0  เมื่อเลิกงานเดินเหงา มีเงาเป็นเพื่อนเข้าซอย\r\...
# 1  หัวใจติดดิน สวมกางเกงยีนส์เก่าๆ\r\nใส่เสื้อตัว...
# 2  สาวรากหญ้า เข้ามาขายแรงเมืองใหญ่\r\nแต่งตัวเหม...
# 3  เนิ่นนาน ที่เราเดินตามฝัน\r\nจากบ้านมาไกล จากท...
# 4  ร้องเพลงพอไปวัดไปวา\r\nแต่จับไมค์ขึ้นมา แล้วเป...
#
#                                      verse_processed  \
# 0  เมื่อ|เลิกงาน|เดิน|เหงา|มี|เงา|เป็นเพื่อน|เข้า...
# 1  หัวใจ|ติด|ดิน|สวม|กางเกง|ยีนส์|เก่าๆ|ใส่|เสื้อ...
# 2  สาว|รากหญ้า|เข้ามา|ขาย|แรง|เมือง|ใหญ่|แต่งตัว|...
# 3  เนิ่นนาน|ที่|เรา|เดินตาม|ฝัน|จาก|บ้าน|มา|ไกล|จ...
# 4  ร้องเพลง|พอ|ไป|วัด|ไป|วา|แต่|จับ|ไมค์|ขึ้น|มา|...
#
#                              verse_removed_stopwords  \
# 0  เลิกงาน|เดิน|เหงา|เงา|เป็นเพื่อน|ซอย|สาว|บ้าน|...
# 1  หัวใจ|ติด|ดิน|สวม|กางเกง|ยีนส์|เก่าๆ|ใส่|เสื้อ...
# 2  สาว|รากหญ้า|เข้ามา|ขาย|แรง|เมือง|แต่งตัว|เหมือ...
# 3  เนิ่นนาน|เดินตาม|ฝัน|บ้าน|ทุ่งนา|เขียว|ภูเขา|ท...
# 4  ร้องเพลง|วัด|วา|ไมค์|เป็นเรื่อง|อาศัย|ความจำ|ด...
#
#                                           pre_chorus  \
# 0  อยากมีพี่เลี้ยง เคียงข้างบนทางเปื้อนฝุ่น\r\nมอ...
# 1  อยู่เมืองสวรรค์ แต่เป็นคนชั้นติดดิน\r\nเป็นผู้...
# 2  เก็บ ใจ มั่น อดออมทุกวันทุกอย่าง\r\nของใช้ก็ซื...
# 3  เหงาจัง กลับห้องมามีเพื่อนก็เพียงเสียงเพลง\r\n...
# 4  หวัด ดีค่ะ อะโหล อะโหล\r\nอยากให้โชว์กี่เพลง ล...
#
#                                 pre_chorus_processed  \
# 0  อยาก|มี|พี่เลี้ยง|เคียง|ข้างบน|ทาง|เปื้อน|ฝุ่น...
# 1  อยู่|เมืองสวรรค์|แต่|เป็น|คน|ชั้น|ติด|ดิน|เป็น...
# 2  เก็บ|ใจ|มั่น|อดออม|ทุกวัน|ทุกอย่าง|ของใช้|ก็|ซ...
# 3  เหงา|จัง|กลับ|ห้อง|มา|มี|เพื่อน|ก็|เพียง|เสียง...
# 4  หวัด|ดี|ค่ะ|อะ|โหล|อะ|โหล|อยาก|ให้|โชว์|กี่|เพ...
#
#                         pre_chorus_removed_stopwords  \
# 0  พี่เลี้ยง|เคียง|เปื้อน|ฝุ่น|มอบ|ใจ|อุ่นๆ|หนาว|...
# 1  เมืองสวรรค์|คน|ชั้น|ติด|ดิน|ผู้รับใช้|ชิน|หู|ไ...
# 2  ใจ|มั่น|อดออม|ของใช้|ซื้อ|ห้าง|ตังค์|ทางบ้าน|ค...
# 3  เหงา|ห้อง|เพื่อน|เสียงเพลง|วันที่|ปัญหา|หอบ|ภา...
# 4  หวัด|ดี|อะ|โหล|อะ|โหล|โชว์|กี่|เพลง|ล่ะ|ขอให้|...
#
#                                               chorus  \
# 0  ขอพึ่งแรงแห่งฝัน บันดาลให้เจอคนดี\r\nให้สาวไกล...
# 1  หัวใจติดดิน สวมกางเกงยีนส์เก่าๆ\r\nใส่เสื้อตัว...
# 2  แก้มใสบ่ให้ตกสี ทำหน้าที่บ่ให้ตกค้าง\r\nรับใช้...
# 3  ยืนบนถนนคนสู้เพื่อฝันลำพัง\r\nคว้างดังเศษฟางที...
# 4  เป็นนักร้องยามมีงานเลี้ยง\r\nมีโทนเสียงอยู่นอก...
#
#                                     chorus_processed  \
# 0  ขอ|พึ่ง|แรง|แห่ง|ฝัน|บันดาล|ให้|เจอ|คนดี|ให้|ส...
# 1  หัวใจ|ติด|ดิน|สวม|กางเกง|ยีนส์|เก่าๆ|ใส่|เสื้อ...
# 2  แก้ม|ใส|บ่|ให้|ตก|สี|ทำหน้าที่|บ่|ให้|ตกค้าง|ร...
# 3  ยืน|บน|ถนน|คน|สู้|เพื่อ|ฝัน|ลำพัง|คว้าง|ดัง|เศ...
# 4  เป็น|นักร้อง|ยาม|มี|งานเลี้ยง|มี|โทน|เสียง|อยู...
#
#                             chorus_removed_stopwords  \
# 0  แรง|ฝัน|บันดาล|เจอ|คนดี|สาว|บ้าน|คน|คน|คอย|ปลอ...
# 1  หัวใจ|ติด|ดิน|สวม|กางเกง|ยีนส์|เก่าๆ|ใส่|เสื้อ...
# 2  แก้ม|ใส|บ่|ตก|สี|ทำหน้าที่|บ่|ตกค้าง|รับใช้|ตั...
# 3  ยืน|ถนน|คน|สู้|ฝัน|ลำพัง|คว้าง|เศษ|ฟาง|ถู|กลม|...
# 4  นักร้อง|ยาม|งานเลี้ยง|โทน|เสียง|สายตา|แมวมอง|เ...
#
#                                 lyrics_all_processed  \
# 0  อยาก|มี|พี่เลี้ยง|เคียง|ข้างบน|ทาง|เปื้อน|ฝุ่น...
# 1  อยู่|เมืองสวรรค์|แต่|เป็น|คน|ชั้น|ติด|ดิน|เป็น...
# 2  เก็บ|ใจ|มั่น|อดออม|ทุกวัน|ทุกอย่าง|ของใช้|ก็|ซ...
# 3  เหงา|จัง|กลับ|ห้อง|มา|มี|เพื่อน|ก็|เพียง|เสียง...
# 4  หวัด|ดี|ค่ะ|อะ|โหล|อะ|โหล|อยาก|ให้|โชว์|กี่|เพ...
#
#                         lyrics_all_removed_stopwords
# 0  พี่เลี้ยง|เคียง|เปื้อน|ฝุ่น|มอบ|ใจ|อุ่นๆ|หนาว|...
# 1  เมืองสวรรค์|คน|ชั้น|ติด|ดิน|ผู้รับใช้|ชิน|หู|ไ...
# 2  ใจ|มั่น|อดออม|ของใช้|ซื้อ|ห้าง|ตังค์|ทางบ้าน|ค...
# 3  เหงา|ห้อง|เพื่อน|เสียงเพลง|วันที่|ปัญหา|หอบ|ภา...
# 4  หวัด|ดี|อะ|โหล|อะ|โหล|โชว์|กี่|เพลง|ล่ะ|ขอให้|...

# %%
'''
Display Documents Info.
'''
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500 entries, 0 to 1499
# Data columns (total 17 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   id                            1500 non-null   int64
#  1   title                         1500 non-null   object
#  2   artist                        1500 non-null   object
#  3   emotion                       1500 non-null   object
#  4   emotion_sym                   1500 non-null   int64
#  5   year                          1500 non-null   int64
#  6   verse                         1500 non-null   object
#  7   verse_processed               1500 non-null   object
#  8   verse_removed_stopwords       1500 non-null   object
#  9   pre_chorus                    1500 non-null   object
#  10  pre_chorus_processed          1500 non-null   object
#  11  pre_chorus_removed_stopwords  1500 non-null   object
#  12  chorus                        1500 non-null   object
#  13  chorus_processed              1500 non-null   object
#  14  chorus_removed_stopwords      1500 non-null   object
#  15  lyrics_all_processed          1500 non-null   object
#  16  lyrics_all_removed_stopwords  1500 non-null   object
# dtypes: int64(3), object(14)
# memory usage: 199.3+ KB

# %% [markdown]
# ### นำเฉพาะบางส่วนของเอกสารมาใช้สำหรับสร้างโมเดล

# %%
'''
Use only some past of document (Hook)
'''
documents = data["lyrics_all_processed"].values

# %%
documents[0:3]
# Out:
# array(['อยาก|มี|พี่เลี้ยง|เคียง|ข้างบน|ทาง|เปื้อน|ฝุ่น|มอบ|ใจ|อุ่นๆ|กัน|หนาว|กัน|ท้อ|พอเพียง|ยาม|เจ็บ|เห็น|หน้า|ยาม|มีปัญหา|ยืน|เคียง|ยาม|เหงา|ได้|โทร|ฟัง|เสียง|หล่อเลี้ยง|หัวใจ|ทุกคราว|ขอ|พึ่ง|แรง|แห่ง|ฝัน|บันดาล|ให้|เจอ|คนดี|ให้|สาว|ไกล|บ้าน|คน|นี้|ได้|มี|คน|คอย|ปลอบ|เหงา|งาน|ยุ่ง|เมือง|ใหญ่|ขอ|ใจ|ฮัก|มั่น|กัน|หนาว|นำพา|ใน|ทุก|เรื่องราว|ให้|สาว|ดอก|หญ้า|อุ่นใจ|เมื่อ|เลิกงาน|เดิน|เหงา|มี|เงา|เป็นเพื่อน|เข้า|ซอย|ผู้|สาว|บ้าน|ไกล|ใจลอย|บ่|มี|คน|คอย|เคียง|เงา|อยู่|ใน|เมือง|ใหญ่|อุ่น|กาย|แต่|หัวใจ|หนาว|วัน|มี|หลาย|เรื่องราว|รุมเร้า|ให้|คอย|หวั่นไหว|ฝืน|ยืน|สู้|แค่|ไหน|นาน|ไป|แรงใจ|สึกหรอ|ห่วงใย|ทางบ้าน|ที่|รอ|แม่|พ่อ|จั๊ก|อยู่|จั่งได๋|ปัญหา|หลายอย่าง|สู้|ตามลำพัง|บ่|ไหว|พรุ่งนี้|สิ|เดิน|อย่างไร|ถ้า|ใจ|บ่|มี|คน|เคียง',
#        'อยู่|เมืองสวรรค์|แต่|เป็น|คน|ชั้น|ติด|ดิน|เป็น|ผู้รับใช้|จน|ชิน|หู|ได้ยิน|แต่|คำ|สั่งงาน|แต่|ยัง|ยิ้ม|ได้|เพราะ|ใจ|เหมือน|ดอก|หญ้า|บาน|ถึง|อยู่|ใน|ที่ต่ำ|ชั้น|แต่|ก็|บาน|ได้|ทุกเวลา|หัวใจ|ติด|ดิน|สวม|กางเกง|ยีนส์|เก่าๆ|ใส่|เสื้อ|ตัว|ร้อย|เก้า|แต่|ใจ|สาว|บ่|ด้อย|ราคา|หวัง|ไว้|วันหนึ่ง|เรียนจบ|ชั้น|ที่|เฝ้ารอ|มา|จะ|สวมมงกุฎ|ดอก|หญ้า|ถ่ายรูป|ปริญญา|หวน|มา|บ้าน|เรา|หัวใจ|ติด|ดิน|สวม|กางเกง|ยีนส์|เก่าๆ|ใส่|เสื้อ|ตัว|ร้อย|เก้า|กอด|กระเป๋า|ใบ|เดียว|ติด|กาย|กราบลา|แม่|พ่อ|หลังจาก|เรียนจบ|ม.|ปลาย|ลา|ทุ่ง|ดอก|คูณ|ไสว|มา|อาศัย|ชายคา|ป่า|ปูน|เอาแรง|เป็น|ทุน|สู้|งาน|เงินเดือน|ต่ำ|ต่ำ|เก็บ|เงิน|เข้าเรียน|ภาค|ค่ำ|ก่อ|ความหวัง|บน|ทาง|เปื้อน|ฝุ่น|สังคมเมือง|ใหญ่|ขาดแคลน|น้ำใจ|เจือจุน|ใช้|ความอดทน|เติม|ทุน|ให้|ยืน|สู้|ไหว|ทุกวัน',
#        'เก็บ|ใจ|มั่น|อดออม|ทุกวัน|ทุกอย่าง|ของใช้|ก็|ซื้อ|นอก|ห้าง|จึง|พอ|มี|ตังค์|ส่ง|ให้|ทางบ้าน|ส่วน|คน|เป็น|คู่เคียง|ใจ|น้อง|เรียนจบ|จึง|ค่อย|คิด|กัน|ฟัง|เพลงลูกทุ่ง|ปลอบ|ฝัน|ให้|ใจ|ก้าว|ผ่าน|วัน|บ่|มี|แฟน|แก้ม|ใส|บ่|ให้|ตก|สี|ทำหน้าที่|บ่|ให้|ตกค้าง|รับใช้|จึง|ได้รับ|ตังค์|ต้อง|ใช้กำลัง|ทุก|งาน|ที่|ทำ|เป็น|กรรมกร|แก้มแดง|ขาย|แรง|ใน|ชุด|งาม|ตาม|ร้าน|ตาม|ห้าง|ตาม|ปั๊ม|มี|เพื่อน|เรา|ทำ|ทุก|ตำแหน่งงาน|สาว|รากหญ้า|เข้ามา|ขาย|แรง|เมือง|ใหญ่|แต่งตัว|เหมือน|เป็น|เจ้านาย|แต่|อยู่|ฝ่าย|ให้บริการ|เดินทาง|มาจาก|บ้านนอก|ทำงานหนัก|เงินเดือน|หลัก|พัน|ตาก|แอร์|ใน|ที่ทำงาน|กลับ|เมือ|บ้าน|นอน|ห้อง|พัดลม|เหนื่อย|ห้าม|ท้อ|หน้างอ|เงินเดือน|บ่|ออก|ท่อง|คำ|เจ้านาย|เพิ่น|บอก|ยิ้ม|ให้|ออก|ถึงใจ|ซานซม|แอบ|ร้องไห้|ใน|ห้องน้ำ|เมื่อ|โดน|คำ|ย่ำ|ใจ|ขื่นขม|คนจน|ล่ะ|บ่|มีสิทธิ์|จ่ม|ซ่อน|อารมณ์|หลัง|รอยยิ้ม|งาม'],
#       dtype=object)

# %% [markdown]
# ### แปลงเอกสารให้กลายเป็น Train Corpus ด้วย Doc2Vec - TaggedDocument

# %%
'''
Convert Documents to Train Corpus by Using Gensim Doc2Vec
'''
train_corpus = []
i = 1
for doc in documents:
    train_corpus.append(gensim.models.doc2vec.TaggedDocument(doc.split("|"), [i]))
    i += 1

# %%
train_corpus[0:3]
# Out:
# [TaggedDocument(words=['อยาก', 'มี', 'พี่เลี้ยง', 'เคียง', 'ข้างบน', 'ทาง', 'เปื้อน', 'ฝุ่น', 'มอบ', 'ใจ', 'อุ่นๆ', 'กัน', 'หนาว', 'กัน', 'ท้อ', 'พอเพียง', 'ยาม', 'เจ็บ', 'เห็น', 'หน้า', 'ยาม', 'มีปัญหา', 'ยืน', 'เคียง', 'ยาม', 'เหงา', 'ได้', 'โทร', 'ฟัง', 'เสียง', 'หล่อเลี้ยง', 'หัวใจ', 'ทุกคราว', 'ขอ', 'พึ่ง', 'แรง', 'แห่ง', 'ฝัน', 'บันดาล', 'ให้', 'เจอ', 'คนดี', 'ให้', 'สาว', 'ไกล', 'บ้าน', 'คน', 'นี้', 'ได้', 'มี', 'คน', 'คอย', 'ปลอบ', 'เหงา', 'งาน', 'ยุ่ง', 'เมือง', 'ใหญ่', 'ขอ', 'ใจ', 'ฮัก', 'มั่น', 'กัน', 'หนาว', 'นำพา', 'ใน', 'ทุก', 'เรื่องราว', 'ให้', 'สาว', 'ดอก', 'หญ้า', 'อุ่นใจ', 'เมื่อ', 'เลิกงาน', 'เดิน', 'เหงา', 'มี', 'เงา', 'เป็นเพื่อน', 'เข้า', 'ซอย', 'ผู้', 'สาว', 'บ้าน', 'ไกล', 'ใจลอย', 'บ่', 'มี', 'คน', 'คอย', 'เคียง', 'เงา', 'อยู่', 'ใน', 'เมือง', 'ใหญ่', 'อุ่น', 'กาย', 'แต่', 'หัวใจ', 'หนาว', 'วัน', 'มี', 'หลาย', 'เรื่องราว', 'รุมเร้า', 'ให้', 'คอย', 'หวั่นไหว', 'ฝืน', 'ยืน', 'สู้', 'แค่', 'ไหน', 'นาน', 'ไป', 'แรงใจ', 'สึกหรอ', 'ห่วงใย', 'ทางบ้าน', 'ที่', 'รอ', 'แม่', 'พ่อ', 'จั๊ก', 'อยู่', 'จั่งได๋', 'ปัญหา', 'หลายอย่าง', 'สู้', 'ตามลำพัง', 'บ่', 'ไหว', 'พรุ่งนี้', 'สิ', 'เดิน', 'อย่างไร', 'ถ้า', 'ใจ', 'บ่', 'มี', 'คน', 'เคียง'], tags=[1]),
#  TaggedDocument(words=['อยู่', 'เมืองสวรรค์', 'แต่', 'เป็น', 'คน', 'ชั้น', 'ติด', 'ดิน', 'เป็น', 'ผู้รับใช้', 'จน', 'ชิน', 'หู', 'ได้ยิน', 'แต่', 'คำ', 'สั่งงาน', 'แต่', 'ยัง', 'ยิ้ม', 'ได้', 'เพราะ', 'ใจ', 'เหมือน', 'ดอก', 'หญ้า', 'บาน', 'ถึง', 'อยู่', 'ใน', 'ที่ต่ำ', 'ชั้น', 'แต่', 'ก็', 'บาน', 'ได้', 'ทุกเวลา', 'หัวใจ', 'ติด', 'ดิน', 'สวม', 'กางเกง', 'ยีนส์', 'เก่าๆ', 'ใส่', 'เสื้อ', 'ตัว', 'ร้อย', 'เก้า', 'แต่', 'ใจ', 'สาว', 'บ่', 'ด้อย', 'ราคา', 'หวัง', 'ไว้', 'วันหนึ่ง', 'เรียนจบ', 'ชั้น', 'ที่', 'เฝ้ารอ', 'มา', 'จะ', 'สวมมงกุฎ', 'ดอก', 'หญ้า', 'ถ่ายรูป', 'ปริญญา', 'หวน', 'มา', 'บ้าน', 'เรา', 'หัวใจ', 'ติด', 'ดิน', 'สวม', 'กางเกง', 'ยีนส์', 'เก่าๆ', 'ใส่', 'เสื้อ', 'ตัว', 'ร้อย', 'เก้า', 'กอด', 'กระเป๋า', 'ใบ', 'เดียว', 'ติด', 'กาย', 'กราบลา', 'แม่', 'พ่อ', 'หลังจาก', 'เรียนจบ', 'ม.', 'ปลาย', 'ลา', 'ทุ่ง', 'ดอก', 'คูณ', 'ไสว', 'มา', 'อาศัย', 'ชายคา', 'ป่า', 'ปูน', 'เอาแรง', 'เป็น', 'ทุน', 'สู้', 'งาน', 'เงินเดือน', 'ต่ำ', 'ต่ำ', 'เก็บ', 'เงิน', 'เข้าเรียน', 'ภาค', 'ค่ำ', 'ก่อ', 'ความหวัง', 'บน', 'ทาง', 'เปื้อน', 'ฝุ่น', 'สังคมเมือง', 'ใหญ่', 'ขาดแคลน', 'น้ำใจ', 'เจือจุน', 'ใช้', 'ความอดทน', 'เติม', 'ทุน', 'ให้', 'ยืน', 'สู้', 'ไหว', 'ทุกวัน'], tags=[2]),
#  TaggedDocument(words=['เก็บ', 'ใจ', 'มั่น', 'อดออม', 'ทุกวัน', 'ทุกอย่าง', 'ของใช้', 'ก็', 'ซื้อ', 'นอก', 'ห้าง', 'จึง', 'พอ', 'มี', 'ตังค์', 'ส่ง', 'ให้', 'ทางบ้าน', 'ส่วน', 'คน', 'เป็น', 'คู่เคียง', 'ใจ', 'น้อง', 'เรียนจบ', 'จึง', 'ค่อย', 'คิด', 'กัน', 'ฟัง', 'เพลงลูกทุ่ง', 'ปลอบ', 'ฝัน', 'ให้', 'ใจ', 'ก้าว', 'ผ่าน', 'วัน', 'บ่', 'มี', 'แฟน', 'แก้ม', 'ใส', 'บ่', 'ให้', 'ตก', 'สี', 'ทำหน้าที่', 'บ่', 'ให้', 'ตกค้าง', 'รับใช้', 'จึง', 'ได้รับ', 'ตังค์', 'ต้อง', 'ใช้กำลัง', 'ทุก', 'งาน', 'ที่', 'ทำ', 'เป็น', 'กรรมกร', 'แก้มแดง', 'ขาย', 'แรง', 'ใน', 'ชุด', 'งาม', 'ตาม', 'ร้าน', 'ตาม', 'ห้าง', 'ตาม', 'ปั๊ม', 'มี', 'เพื่อน', 'เรา', 'ทำ', 'ทุก', 'ตำแหน่งงาน', 'สาว', 'รากหญ้า', 'เข้ามา', 'ขาย', 'แรง', 'เมือง', 'ใหญ่', 'แต่งตัว', 'เหมือน', 'เป็น', 'เจ้านาย', 'แต่', 'อยู่', 'ฝ่าย', 'ให้บริการ', 'เดินทาง', 'มาจาก', 'บ้านนอก', 'ทำงานหนัก', 'เงินเดือน', 'หลัก', 'พัน', 'ตาก', 'แอร์', 'ใน', 'ที่ทำงาน', 'กลับ', 'เมือ', 'บ้าน', 'นอน', 'ห้อง', 'พัดลม', 'เหนื่อย', 'ห้าม', 'ท้อ', 'หน้างอ', 'เงินเดือน', 'บ่', 'ออก', 'ท่อง', 'คำ', 'เจ้านาย', 'เพิ่น', 'บอก', 'ยิ้ม', 'ให้', 'ออก', 'ถึงใจ', 'ซานซม', 'แอบ', 'ร้องไห้', 'ใน', 'ห้องน้ำ', 'เมื่อ', 'โดน', 'คำ', 'ย่ำ', 'ใจ', 'ขื่นขม', 'คนจน', 'ล่ะ', 'บ่', 'มีสิทธิ์', 'จ่ม', 'ซ่อน', 'อารมณ์', 'หลัง', 'รอยยิ้ม', 'งาม'], tags=[3])]

# %% [markdown]
# ### สร้าง Doc2Vec Model

# %%
'''
Create Doc2Vec Model
'''
model = gensim.models.doc2vec.Doc2Vec(vector_size=200, min_count=2, epochs=40)

# %%
'''
Create Vocabulary
'''
model.build_vocab(train_corpus)

# %%
'''
Train model with train corpus
'''
model.train(train_corpus, total_examples=model.corpus_count, epochs=model.epochs)

# %% [markdown]
# ### ทดสอบโมเดลครั้งที่ 1. หาเอกสารที่มีความคล้ายคลึงกับทุกเอกสารภายใน Corpus

# %%
'''
Find Similarity of earch documents
'''
ranks = []
second_ranks = []

for doc_id in range(len(train_corpus)):
    inferred_vector = model.infer_vector(train_corpus[doc_id].words)
    
    sims = model.docvecs.most_similar([inferred_vector], topn=len(model.docvecs))
    
    rank = [docid for docid, sim in sims].index(doc_id)
    
    ranks.append(rank)
    
    second_ranks.append(sims[1])

# %% [markdown]
# ### ทดสอบโมเดลครั้งที่ 2. หาเอกสารที่มีความคล้ายคลึงกับเอกสารสุดท้ายใน Corpus

# %%
'''
Test the model !!
By find similarity of last document
'''
'''
print('Document ({}): «{}»\n'.format(doc_id, ''.join(train_corpus[doc_id].words)))

print(u'SIMILAR/DISSIMILAR DOCS PER MODEL %s:\n' % model)

for label, index in [('MOST', 0), ('SECOND-MOST', 1), ('MEDIAN', len(sims)//2), ('LEAST', len(sims) - 1)]:
    print(u'%s %s: «%s»\n' % (label, sims[index], ''.join(train_corpus[sims[index][0]].words)))
'''
# Out:
# "\nprint('Document ({}): «{}»\n'.format(doc_id, ''.join(train_corpus[doc_id].words)))\n\nprint(u'SIMILAR/DISSIMILAR DOCS PER MODEL %s:\n' % model)\n\nfor label, index in [('MOST', 0), ('SECOND-MOST', 1), ('MEDIAN', len(sims)//2), ('LEAST', len(sims) - 1)]:\n    print(u'%s %s: «%s»\n' % (label, sims[index], ''.join(train_corpus[sims[index][0]].words)))\n"

# %% [markdown]
# ### ทดสอบโมเดลครั้งที่ 3. หาเอกสารที่มีความคล้ายคลึงกับเอกสารที่ถูกสุ่มขึ้นมา

# %%
'''
Test the model !!
By find similarity of radcom id document
Pick a random document from the corpus and infer a vector from the model
'''
doc_id = random.randint(0, len(train_corpus) - 1)

# Compare and print the second-most-similar document
print('Train Document ({}): «{}»\n'.format(doc_id, ''.join(train_corpus[doc_id].words)))

sim_id = second_ranks[doc_id]

print('Similar Document {}: «{}»\n'.format(sim_id, ''.join(train_corpus[sim_id[0]].words)))

# ---------------------------------------------------------------------------------------
# Out:
# Train Document (534): «จึงเทคแคร์เธอได้เพียงไม่ให้มีเสียงหลุดมาจากปากเงียบไปไม่ใช่ไม่รักแต่ไม่อยากพูดคำไม่ดีก็คนกำลังน้อยใจไม่อยากพูดกับใครในตอนนี้นอนให้ความเงียบเยียวยาปรึกษากับความเจ็บอีกทีแผลช้ำที่เธอย่ำยียังไม่เจอวิธีเคลียร์ใจหาไม่เจอวิธีเคลียร์ใจเธอไม่เหมือนเก่าแต่อยากให้เราเหมือนก่อนไม่อยากให้ใครเขางอนแต่ตอนทำแล้วแคร์ไหมเดินแวะไปใกล้ใครเขาแต่อยากให้เราเข้าใจคนนอกใจกันมันง่ายแต่คนทำใจมันยากทำผิดซะมากมายแต่ไม่อยากให้ใครเขาบ่นถ้าฉันคบใครอีกคนแล้วเธอจะทนได้ไหมไหนว่ามีใจให้กันกับคนนั้นมันคืออะไรแค่เผลออาจพอรับได้นี่มันมากไปจนยาก»
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-87-6072315945e7> in <module>
#      11 sim_id = ranks[doc_id]
#      12
# ---> 13 print('Most Similar Document {}: «{}»\n'.format(sim_id, ''.join(train_corpus[sim_id[0]].words)))
#      14
#      15 # ---------------------------------------------------------------------------------------
#
# TypeError: 'int' object is not subscriptable

# %% [markdown]
# ### ทดสอบโมเดลครั้งที่ 4. หาเอกสารที่มีความคล้ายคลึงกับ input document
#
# 1. รับเอกสารเข้ามา
# 1. ทำการแปลงเอกสารที่รับเข้ามาให้อยู่ในรูปแบบของ Infer_vector
# 1. นำเอา Infer_vector ไปทำการค้นหาความคล้ายกับ Model

# %%
'''
Test the model !!
By get input document and transform it into infer vector
'''

doc_org = 'ขอ|พึ่ง|แรง|แห่ง|ฝัน|บันดาล|ให้|เจอ|คนดี|ให้|สาว|ไกล|บ้าน|คน|นี้|ได้|มี|คน|คอย|ปลอบ|เหงา|งาน|ยุ่ง|เมือง|ใหญ่|ขอ|ใจ|ฮัก|มั่น|กัน|หนาว|นำพา|ใน|ทุก|เรื่องราว|ให้|สาว|ดอก|หญ้า|อุ่นใจ'

# ตัดทอน Tokens บางตัวออกไป
# doc_input = 'ขอ|พึ่ง|แรง|แห่ง|ฝัน|ให้|เจอ|คนดี|ให้|สาว|คน|นี้|ได้|มี|คน|คอย|ปลอบ|เหงา|เมือง|ใหญ่|ขอ|ใจ|ฮัก|มั่น|กัน|หนาว|นำพา|ใน|ทุก|เรื่องราว|ให้|สาว|ดอก|หญ้า|อุ่นใจ'

test_vec = doc_input.split("|")

inferred_vector = model.infer_vector(test_vec)

sims = model.docvecs.most_similar([inferred_vector], topn=len(model.docvecs))

# Compare and print the most/median/least similar documents from the train corpus
print('Test Document: «{}»\n'.format(' '.join(test_vec)))

print(u'SIMILAR/DISSIMILAR DOCS PER MODEL %s:\n' % model)
for label, index in [('MOST', 0), ('MEDIAN', len(sims)//2), ('LEAST', len(sims) - 1)]:
    print(u'%s %s: «%s»\n' % (label, sims[index], ''.join(train_corpus[sims[index][0]].words)))

# ---------------------------------------------------------------------------------------
# Out:
# Test Document: «ขอ พึ่ง แรง แห่ง ฝัน ให้ เจอ คนดี ให้ สาว คน นี้ ได้ มี คน คอย ปลอบ เหงา เมือง ใหญ่ ขอ ใจ ฮัก มั่น กัน หนาว นำพา ใน ทุก เรื่องราว ให้ สาว ดอก หญ้า อุ่นใจ»
#
# SIMILAR/DISSIMILAR DOCS PER MODEL Doc2Vec(dm/m,d200,n5,w5,mc2,s0.001,t3):
#
# MOST (1, 0.7331886291503906): «อยู่เมืองสวรรค์แต่เป็นคนชั้นติดดินเป็นผู้รับใช้จนชินหูได้ยินแต่คำสั่งงานแต่ยังยิ้มได้เพราะใจเหมือนดอกหญ้าบานถึงอยู่ในที่ต่ำชั้นแต่ก็บานได้ทุกเวลาหัวใจติดดินสวมกางเกงยีนส์เก่าๆใส่เสื้อตัวร้อยเก้าแต่ใจสาวบ่ด้อยราคาหวังไว้วันหนึ่งเรียนจบชั้นที่เฝ้ารอมาจะสวมมงกุฎดอกหญ้าถ่ายรูปปริญญาหวนมาบ้านเราหัวใจติดดินสวมกางเกงยีนส์เก่าๆใส่เสื้อตัวร้อยเก้ากอดกระเป๋าใบเดียวติดกายกราบลาแม่พ่อหลังจากเรียนจบม.ปลายลาทุ่งดอกคูณไสวมาอาศัยชายคาป่าปูนเอาแรงเป็นทุนสู้งานเงินเดือนต่ำต่ำเก็บเงินเข้าเรียนภาคค่ำก่อความหวังบนทางเปื้อนฝุ่นสังคมเมืองใหญ่ขาดแคลนน้ำใจเจือจุนใช้ความอดทนเติมทุนให้ยืนสู้ไหวทุกวัน»
#
# MEDIAN (1153, 0.17183855175971985): «ใช่อยากหวนคืนไปรักกับเขาแค่ใจดวงเก่าอยากฟังเสียงเขาปลอบโยนอีกครั้งถึงทำให้ฉันช้ำใจก็ใช่ว่าต้องเกลียดชังวอนผ่านสายลมเบาบางให้เขาโทรถามบ้างยังดีเขาเคยอยู่ข้างฉันในวันฟ้าหม่นเป็นมือหนึ่งของคนที่คอยปลอบใจอกร้าววันนี้เพราะเขาไปมีรักใหม่ไม่เหลือความรักไว้ให้ก็เหลือความห่วงใยไว้บ้างรู้ข่าวว่าฉันอกร้าวเพราะรักเพื่อนคนรู้จักต่างมาถามทักด้วยความห่วงใยบ้างชวนคุยเรื่องขำเพื่อห้ามน้ำตาที่ไหลบ้างบอกไม่ต้องร้องไห้เอ่ยจากใจของผู้หวังดีซึ้งกับน้ำใจหลั่งไหลท่วมท้นแต่ความหมองหม่นกลับยังเอ่อล้นในใจดวงนี้ยิ่งมีคนมาปลอบใจน้ำตายิ่งไหลทุกทีเพราะมันย้ำใจว่ามีผู้หวังดีอีกคนหายไป»
#
# LEAST (807, -0.12855510413646698): «แค่อยากอิบอกอิแหลงให้ฟังอย่ามาทำควันขวันยุแถวนี้ที่เลิกกับพี่น้องเห็นได้ดีทุกคนพอพี่เปิดเผยตัวตนคนกะหันหลังอย่ามาปากหวานไม่อยากให้คิดจริงจังก็แค่อยากอิหลอกฟันเขาแหลงว่าบ่าวนั้นหรอยรู้จักกันจริงน้องนิชอบเหยียบถอยต้องโบกมือบ่ายบายแล้วแขบใส่เกียร์หมาลีลาไม่ผ่านแล้วยังเจ้าชู้แค่ตายสันดานเหมือนผีแล้วยังทำผีพอได้ปัดโถ่เอ้ยไอ้ฟายไปหลายใจไกลๆกะยอมรับน่ะว่าบ่าวนั้นหล่อแต่ว่าบ่าวหัวหมอเจ้าชู้ไม่เอาไหนแรกหัวเช้าควงน้องไอซ์เดินห้างแต่พอหวันส่างควงน้องปางไปไหนโฉ้ไอ้คำพูดของบ่าวช่างมากหนัดเหนียนสาวคนไหนห้ามเถียงบ่าวทำเซียนเหมือนเรียนมาไอ้นั้นพันนี้ไอ้นี้พันนั้นไอยาลังกาไปหลอกเด็กต่ะใครเชื่อก็บ้าแล้ว»

# %% [markdown]
# ### บันทึกโมเดลเพื่อนำไปใช้งานต่อไป

# %%
'''
Save the Doc2Vec model
'''
model.save('./model/model_docvec.d2v')
